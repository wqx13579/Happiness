# %% [markdown]
# # Questions, Dataset and motivation section.(2 point)

# %%
import pandas as pd

# %%
happy_2015 = pd.read_csv("2015.csv")
happy_2016 = pd.read_csv("2016.csv")
happy_2017 = pd.read_csv("2017.csv")
happy_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happy_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happy_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %% [markdown]
# # Quality of cleaning (3 points, 1 points each)

# %% [markdown]
# Drop the columns which are not useful for or problem. We need to analyze the main factors of making people happy so we eliminate the Happiness Rank, Standard Error, Lower Confidence Interval, Upper Confidence Interval, Whisker.high, and Whisker.low column.

# %%
happy_2015=happy_2015.drop(columns=['Happiness Rank','Standard Error'])
happy_2016=happy_2016.drop(columns=['Happiness Rank','Lower Confidence Interval','Upper Confidence Interval'])
happy_2017=happy_2017.drop(columns=['Whisker.high','Happiness.Rank','Whisker.low'])

# %%
happy_2015.head()
happy_2015.shape
# Out:
# (158, 10)

# %%
happy_2016.head()
happy_2016.shape
# Out:
# (157, 10)

# %%
happy_2017.head()
happy_2017.shape
# Out:
# (155, 9)

# %% [markdown]
# We rename the columns in happy_2017 in order to make the data more readable. Make all the files have the same column name so that we could concatenate all dataframes together into one data frame.

# %%
#happy_2015.rename(index=str, columns={"A": "a", "B": "c"})
#happy_2016.rename(index=str, columns={"A": "a", "B": "c"})
happy_2017=happy_2017.rename(index=str, columns={"Happiness.Score": "Happiness Score", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)","Health..Life.Expectancy.":"Health (Life Expectancy)","Trust..Government.Corruption.":"Trust (Government Corruption)","Dystopia.Residual":"Dystopia Residual"})

# %%
happy_2017.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0       Norway            7.537                  1.616463  1.533524
# 1      Denmark            7.522                  1.482383  1.551122
# 2      Iceland            7.504                  1.480633  1.610574
# 3  Switzerland            7.494                  1.564980  1.516912
# 4      Finland            7.469                  1.443572  1.540247
#
#    Health (Life Expectancy)   Freedom  Generosity  \
# 0                  0.796667  0.635423    0.362012
# 1                  0.792566  0.626007    0.355280
# 2                  0.833552  0.627163    0.475540
# 3                  0.858131  0.620071    0.290549
# 4                  0.809158  0.617951    0.245483
#
#    Trust (Government Corruption)  Dystopia Residual
# 0                       0.315964           2.277027
# 1                       0.400770           2.313707
# 2                       0.153527           2.322715
# ...

# %% [markdown]
# We concatenate all dataframes together into one data frame

# %%
happy = pd.concat([happy_2015,happy_2016,happy_2017],sort=True)
happy.shape
# Out:
# (470, 10)

# %% [markdown]
# For the dataframe happy_2017, it does not have the Region column. So when we concatenate all of the, the Region column have a lot of NaN in it. Therefore we match the Region by the same Country from the dataframe happy_2015 and happy_2016.
#
# The reason we do this is that we want to use Region to analyze happiness. Thus, we have to keep Region and fill all the NaN data.

# %%
g = happy.dropna(subset=['Region']).drop_duplicates('Country').set_index('Country')['Region']
happy['Region'] = happy['Region'].fillna(happy['Country'].map(g))

# %%
happy1 = happy[happy.isna().any(axis=1)]
happy1
# Out:
#                      Country  Dystopia Residual  Economy (GDP per Capita)  \
# 32  Taiwan Province of China           2.126607                  1.433627
# 70   Hong Kong S.A.R., China           0.554633                  1.551675
#
#       Family   Freedom  Generosity  Happiness Score  Health (Life Expectancy)  \
# 32  1.384565  0.361467    0.258360            6.422                  0.793984
# 70  1.262791  0.490969    0.374466            5.472                  0.943062
#
#    Region  Trust (Government Corruption)
# 32    NaN                       0.063829
# 70    NaN                       0.293934

# %% [markdown]
# We found two rows still have Region in NaN, we check the Country of these two row and we found both of them are in Eastern Asia, so we fill both Region as Eastern Asia.

# %%
happy = happy.fillna("Eastern Asia")
happy.head()
# Out:
#        Country  Dystopia Residual  Economy (GDP per Capita)   Family  Freedom  \
# 0  Switzerland            2.51738                   1.39651  1.34951  0.66557
# 1      Iceland            2.70201                   1.30232  1.40223  0.62877
# 2      Denmark            2.49204                   1.32548  1.36058  0.64938
# 3       Norway            2.46531                   1.45900  1.33095  0.66973
# 4       Canada            2.45176                   1.32629  1.32261  0.63297
#
#    Generosity  Happiness Score  Health (Life Expectancy)          Region  \
# 0     0.29678            7.587                   0.94143  Western Europe
# 1     0.43630            7.561                   0.94784  Western Europe
# 2     0.34139            7.527                   0.87464  Western Europe
# 3     0.34699            7.522                   0.88521  Western Europe
# 4     0.45811            7.427                   0.90563   North America
#
#    Trust (Government Corruption)
# ...

# %% [markdown]
# # Visualization (4 points, 1 points each)

# %% [markdown]
# # Modelling activity/evaluation/conclusion (5 points equally distributed in following 2 question depending on whether you are building a model or not)

# %% [markdown]
# # Conclusion (2 points)
